# %%
import os
os.environ["PYTHONPYCACHEPREFIX"] = "/tmp/pycache"   # __pycache__ nicht in /Workspace
# !pytest -q /Workspace/Users/kaltenbrunnergeorg@googlemail.com/MLOps/MLOps/tests \
  -o cache_dir=/tmp/pytest_cache \
  --basetemp=/tmp/pytest_tmp
